# %% [markdown]
# # Economic Freedom Index
#
# Welcome all to my notebook! Here I will be taking a look at some interesting global economic data on 186 countries in the world. This data is focused on metrics for economic freedom, and I hope to make some interesting observations as well as do a little machine learning towards the end of this notebook.
#
# ### Some of the things I will attempt to answer:
#
# Is there a relationship between GDP and Unemployment?
#
# Is there a relationship between property rights and judicial effectiveness?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
eci = pd.read_csv('economic_freedom_index2019_data.csv')
eci.head(5)
# Out:
#    CountryID Country Name      WEBNAME                        Region  \
# 0          1  Afghanistan  Afghanistan                  Asia-Pacific
# 1          2      Albania      Albania                        Europe
# 2          3      Algeria      Algeria  Middle East and North Africa
# 3          4       Angola       Angola            Sub-Saharan Africa
# 4          5    Argentina    Argentina                      Americas
#
#    World Rank  Region Rank  2019 Score  Property Rights  \
# 0       152.0         39.0        51.5             19.6
# 1        52.0         27.0        66.5             54.8
# 2       171.0         14.0        46.2             31.6
# 3       156.0         33.0        50.6             35.9
# 4       148.0         26.0        52.2             47.8
#
#    Judical Effectiveness  Government Integrity  ...      Country  \
# 0                   29.6                  25.2  ...  Afghanistan
# 1                   30.6                  40.4  ...      Albania
# 2                   36.2                  28.9  ...      Algeria
# 3                   26.6                  20.5  ...       Angola
# 4                   44.5                  33.5  ...    Argentina
#
#    Population (Millions)  GDP (Billions, PPP)  GDP Growth Rate (%)  \
# 0                   35.5               $69.6                   2.5
# 1                    2.9               $36.0                   3.9
# 2                   41.5              $632.9                   2.0
# 3                   28.2              $190.3                   0.7
# 4                   44.1              $920.2                   2.9
#
#    5 Year GDP Growth Rate (%)  GDP per Capita (PPP)  Unemployment (%)  \
# 0                         2.9                $1,958               8.8
# 1                         2.5               $12,507              13.9
# 2                         3.1               $15,237                10
# 3                         2.9                $6,753               8.2
# 4                         0.7               $20,876               8.7
#
#    Inflation (%)  FDI Inflow (Millions)  Public Debt (% of GDP)
# 0            5.0                   53.9                     7.3
# 1            2.0                 1119.1                    71.2
# 2            5.6                 1203.0                    25.8
# 3           31.7                -2254.5                    65.3
# 4           25.7                11857.0                    52.6
#
# [5 rows x 34 columns]

# %%
eci.shape
# Out:
# (186, 34)

# %%
eci.dtypes
# Out:
# CountryID                        int64
# Country Name                    object
# WEBNAME                         object
# Region                          object
# World Rank                     float64
# Region Rank                    float64
# 2019 Score                     float64
# Property Rights                float64
# Judical Effectiveness          float64
# Government Integrity           float64
# Tax Burden                     float64
# Gov't Spending                 float64
# Fiscal Health                  float64
# Business Freedom               float64
# Labor Freedom                  float64
# Monetary Freedom               float64
# Trade Freedom                  float64
# Investment Freedom             float64
# Financial Freedom              float64
# Tariff Rate (%)                float64
# Income Tax Rate (%)            float64
# Corporate Tax Rate (%)         float64
# Tax Burden % of GDP            float64
# Gov't Expenditure % of GDP     float64
# Country                         object
# Population (Millions)           object
# GDP (Billions, PPP)             object
# GDP Growth Rate (%)            float64
# 5 Year GDP Growth Rate (%)     float64
# GDP per Capita (PPP)            object
# Unemployment (%)                object
# Inflation (%)                  float64
# FDI Inflow (Millions)          float64
# Public Debt (% of GDP)         float64
# dtype: object

# %% [markdown]
# # Exploratory Analysis
#
# Just from taking a peak at some of the observations we can tell right away this dataset has some very interesting features. Let's take a deep dive of them and see if we can tease out some more details.

# %%
## since we have 186 observations, why not group by region?
## group by top 50 rank? bottom 50 rank?

reg_cou = eci.groupby(['Region'])['Business Freedom'].groups
reg_cou
# Out:
# {'Americas': Int64Index([  4,   9,  12,  15,  18,  21,  29,  33,  35,  39,  42,  47,  48,
#               49,  51,  66,  69,  70,  71,  82, 112, 123, 129, 131, 132, 140,
#              141, 158, 169, 177, 178, 181],
#             dtype='int64'),
#  'Asia-Pacific': Int64Index([  0,   6,   8,  11,  17,  22,  25,  27,  34,  57,  72,  75,  76,
#               83,  85,  87,  88,  89,  92,  93, 102, 106, 107, 113, 115, 120,
#              122, 128, 130, 133, 142, 149, 152, 156, 162, 163, 165, 166, 168,
#              172, 179, 180, 182],
#             dtype='int64'),
#  'Europe': Int64Index([  1,   5,   7,  13,  14,  19,  23,  41,  43,  44,  45,  54,  58,
#               59,  62,  63,  65,  73,  74,  79,  81,  90,  94,  99, 100, 101,
#              103, 109, 114, 116, 121, 126, 134, 135, 137, 138, 146, 150, 151,
#              155, 159, 160, 171, 174, 176],
#             dtype='int64'),
#  'Middle East and North Africa': Int64Index([2, 10, 50, 77, 78, 80, 84, 91, 95, 98, 117, 127, 136, 144, 161,
#              170, 175, 183],
#             dtype='int64'),
#  'Sub-Saharan Africa': Int64Index([  3,  16,  20,  24,  26,  28,  30,  31,  32,  36,  37,  38,  40,
#               46,  52,  53,  55,  56,  60,  61,  64,  67,  68,  86,  96,  97,
#              104, 105, 108, 110, 111, 118, 119, 124, 125, 139, 143, 145, 147,
#              148, 153, 154, 157, 164, 167, 173, 184, 185],
#             dtype='int64')}

# %%
regions = eci.groupby(['Region','Country']).groups
regions
# Out:
# {('Americas', 'Argentina'): Int64Index([4], dtype='int64'),
#  ('Americas', 'Bahamas'): Int64Index([9], dtype='int64'),
#  ('Americas', 'Barbados'): Int64Index([12], dtype='int64'),
#  ('Americas', 'Belize'): Int64Index([15], dtype='int64'),
#  ('Americas', 'Bolivia'): Int64Index([18], dtype='int64'),
#  ('Americas', 'Brazil'): Int64Index([21], dtype='int64'),
#  ('Americas', 'Canada'): Int64Index([29], dtype='int64'),
#  ('Americas', 'Chile'): Int64Index([33], dtype='int64'),
#  ('Americas', 'Colombia'): Int64Index([35], dtype='int64'),
#  ('Americas', 'Costa Rica'): Int64Index([39], dtype='int64'),
#  ('Americas', 'Cuba'): Int64Index([42], dtype='int64'),
#  ('Americas', 'Dominica'): Int64Index([47], dtype='int64'),
#  ('Americas', 'Dominican Republic'): Int64Index([48], dtype='int64'),
#  ('Americas', 'Ecuador'): Int64Index([49], dtype='int64'),
#  ('Americas', 'El Salvador'): Int64Index([51], dtype='int64'),
#  ('Americas', 'Guatemala'): Int64Index([66], dtype='int64'),
#  ('Americas', 'Guyana'): Int64Index([69], dtype='int64'),
#  ('Americas', 'Haiti'): Int64Index([70], dtype='int64'),
#  ('Americas', 'Honduras'): Int64Index([71], dtype='int64'),
#  ('Americas', 'Jamaica'): Int64Index([82], dtype='int64'),
#  ('Americas', 'Mexico'): Int64Index([112], dtype='int64'),
#  ('Americas', 'Nicaragua'): Int64Index([123], dtype='int64'),
#  ('Americas', 'Panama'): Int64Index([129], dtype='int64'),
#  ('Americas', 'Paraguay'): Int64Index([131], dtype='int64'),
#  ('Americas', 'Peru'): Int64Index([132], dtype='int64'),
#  ('Americas', 'Saint Lucia'): Int64Index([140], dtype='int64'),
#  ('Americas',
#   'Saint Vincent and the Grenadines'): Int64Index([141], dtype='int64'),
#  ('Americas', 'Suriname'): Int64Index([158], dtype='int64'),
#  ('Americas', 'Trinidad and Tobago'): Int64Index([169], dtype='int64'),
#  ('Americas', 'United States'): Int64Index([177], dtype='int64'),
#  ('Americas', 'Uruguay'): Int64Index([178], dtype='int64'),
#  ('Americas', 'Venezuela'): Int64Index([181], dtype='int64'),
#  ('Asia-Pacific', 'Afghanistan'): Int64Index([0], dtype='int64'),
#  ('Asia-Pacific', 'Australia'): Int64Index([6], dtype='int64'),
#  ('Asia-Pacific', 'Azerbaijan'): Int64Index([8], dtype='int64'),
#  ('Asia-Pacific', 'Bangladesh'): Int64Index([11], dtype='int64'),
#  ('Asia-Pacific', 'Bhutan'): Int64Index([17], dtype='int64'),
#  ('Asia-Pacific', 'Brunei Darussalam'): Int64Index([22], dtype='int64'),
#  ('Asia-Pacific', 'Burma'): Int64Index([25], dtype='int64'),
#  ('Asia-Pacific', 'Cambodia'): Int64Index([27], dtype='int64'),
#  ('Asia-Pacific', 'China'): Int64Index([34], dtype='int64'),
#  ('Asia-Pacific', 'Fiji'): Int64Index([57], dtype='int64'),
#  ('Asia-Pacific', 'Hong Kong SAR'): Int64Index([72], dtype='int64'),
#  ('Asia-Pacific', 'India'): Int64Index([75], dtype='int64'),
#  ('Asia-Pacific', 'Indonesia'): Int64Index([76], dtype='int64'),
#  ('Asia-Pacific', 'Japan'): Int64Index([83], dtype='int64'),
#  ('Asia-Pacific', 'Kazakhstan'): Int64Index([85], dtype='int64'),
#  ('Asia-Pacific', 'Kiribati'): Int64Index([87], dtype='int64'),
#  ('Asia-Pacific', 'Korea, North '): Int64Index([88], dtype='int64'),
#  ('Asia-Pacific', 'Korea, South'): Int64Index([89], dtype='int64'),
#  ('Asia-Pacific', 'Kyrgyz Republic'): Int64Index([92], dtype='int64'),
#  ('Asia-Pacific', 'Lao P.D.R.'): Int64Index([93], dtype='int64'),
#  ('Asia-Pacific', 'Macau'): Int64Index([102], dtype='int64'),
#  ('Asia-Pacific', 'Malaysia'): Int64Index([106], dtype='int64'),
#  ('Asia-Pacific', 'Maldives'): Int64Index([107], dtype='int64'),
#  ('Asia-Pacific', 'Micronesia'): Int64Index([113], dtype='int64'),
#  ('Asia-Pacific', 'Mongolia'): Int64Index([115], dtype='int64'),
#  ('Asia-Pacific', 'Nepal'): Int64Index([120], dtype='int64'),
#  ('Asia-Pacific', 'New Zealand'): Int64Index([122], dtype='int64'),
#  ('Asia-Pacific', 'Pakistan'): Int64Index([128], dtype='int64'),
#  ('Asia-Pacific', 'Papua New Guinea'): Int64Index([130], dtype='int64'),
#  ('Asia-Pacific', 'Philippines'): Int64Index([133], dtype='int64'),
#  ('Asia-Pacific', 'Samoa'): Int64Index([142], dtype='int64'),
#  ('Asia-Pacific', 'Singapore'): Int64Index([149], dtype='int64'),
#  ('Asia-Pacific', 'Solomon Islands'): Int64Index([152], dtype='int64'),
#  ('Asia-Pacific', 'Sri Lanka'): Int64Index([156], dtype='int64'),
#  ('Asia-Pacific', 'Taiwan '): Int64Index([162], dtype='int64'),
#  ('Asia-Pacific', 'Tajikistan'): Int64Index([163], dtype='int64'),
#  ('Asia-Pacific', 'Thailand'): Int64Index([165], dtype='int64'),
#  ('Asia-Pacific', 'Timor-Leste'): Int64Index([166], dtype='int64'),
#  ('Asia-Pacific', 'Tonga'): Int64Index([168], dtype='int64'),
#  ('Asia-Pacific', 'Turkmenistan'): Int64Index([172], dtype='int64'),
#  ('Asia-Pacific', 'Uzbekistan'): Int64Index([179], dtype='int64'),
#  ('Asia-Pacific', 'Vanuatu'): Int64Index([180], dtype='int64'),
#  ('Asia-Pacific', 'Vietnam'): Int64Index([182], dtype='int64'),
#  ('Europe', 'Albania'): Int64Index([1], dtype='int64'),
#  ('Europe', 'Armenia'): Int64Index([5], dtype='int64'),
#  ('Europe', 'Austria'): Int64Index([7], dtype='int64'),
#  ('Europe', 'Belarus'): Int64Index([13], dtype='int64'),
#  ('Europe', 'Belgium'): Int64Index([14], dtype='int64'),
#  ('Europe', 'Bosnia and Herzegovina'): Int64Index([19], dtype='int64'),
#  ('Europe', 'Bulgaria'): Int64Index([23], dtype='int64'),
#  ('Europe', 'Croatia'): Int64Index([41], dtype='int64'),
#  ('Europe', 'Cyprus'): Int64Index([43], dtype='int64'),
#  ('Europe', 'Czech Republic'): Int64Index([44], dtype='int64'),
#  ('Europe', 'Denmark'): Int64Index([45], dtype='int64'),
#  ('Europe', 'Estonia'): Int64Index([54], dtype='int64'),
#  ('Europe', 'Finland'): Int64Index([58], dtype='int64'),
#  ('Europe', 'France'): Int64Index([59], dtype='int64'),
#  ('Europe', 'Georgia'): Int64Index([62], dtype='int64'),
#  ('Europe', 'Germany'): Int64Index([63], dtype='int64'),
#  ('Europe', 'Greece'): Int64Index([65], dtype='int64'),
#  ('Europe', 'Hungary'): Int64Index([73], dtype='int64'),
#  ('Europe', 'Iceland'): Int64Index([74], dtype='int64'),
#  ('Europe', 'Ireland'): Int64Index([79], dtype='int64'),
#  ('Europe', 'Italy'): Int64Index([81], dtype='int64'),
#  ('Europe', 'Kosovo'): Int64Index([90], dtype='int64'),
#  ('Europe', 'Latvia'): Int64Index([94], dtype='int64'),
#  ('Europe', 'Liechtenstein'): Int64Index([99], dtype='int64'),
#  ('Europe', 'Lithuania'): Int64Index([100], dtype='int64'),
#  ('Europe', 'Luxembourg'): Int64Index([101], dtype='int64'),
#  ('Europe', 'Macedonia'): Int64Index([103], dtype='int64'),
#  ('Europe', 'Malta'): Int64Index([109], dtype='int64'),
#  ('Europe', 'Moldova'): Int64Index([114], dtype='int64'),
#  ('Europe', 'Montenegro'): Int64Index([116], dtype='int64'),
#  ('Europe', 'Netherlands'): Int64Index([121], dtype='int64'),
#  ('Europe', 'Norway'): Int64Index([126], dtype='int64'),
#  ('Europe', 'Poland'): Int64Index([134], dtype='int64'),
#  ('Europe', 'Portugal'): Int64Index([135], dtype='int64'),
#  ('Europe', 'Romania'): Int64Index([137], dtype='int64'),
#  ('Europe', 'Russia'): Int64Index([138], dtype='int64'),
#  ('Europe', 'Serbia'): Int64Index([146], dtype='int64'),
#  ('Europe', 'Slovak Republic'): Int64Index([150], dtype='int64'),
#  ('Europe', 'Slovenia'): Int64Index([151], dtype='int64'),
#  ('Europe', 'Spain'): Int64Index([155], dtype='int64'),
#  ('Europe', 'Sweden'): Int64Index([159], dtype='int64'),
#  ('Europe', 'Switzerland'): Int64Index([160], dtype='int64'),
#  ('Europe', 'Turkey'): Int64Index([171], dtype='int64'),
#  ('Europe', 'Ukraine'): Int64Index([174], dtype='int64'),
#  ('Europe', 'United Kingdom'): Int64Index([176], dtype='int64'),
#  ('Middle East and North Africa', 'Algeria'): Int64Index([2], dtype='int64'),
#  ('Middle East and North Africa', 'Bahrain'): Int64Index([10], dtype='int64'),
#  ('Middle East and North Africa', 'Egypt'): Int64Index([50], dtype='int64'),
#  ('Middle East and North Africa', 'Iran'): Int64Index([77], dtype='int64'),
#  ('Middle East and North Africa', 'Iraq'): Int64Index([78], dtype='int64'),
#  ('Middle East and North Africa', 'Israel'): Int64Index([80], dtype='int64'),
#  ('Middle East and North Africa', 'Jordan'): Int64Index([84], dtype='int64'),
#  ('Middle East and North Africa', 'Kuwait'): Int64Index([91], dtype='int64'),
#  ('Middle East and North Africa', 'Lebanon'): Int64Index([95], dtype='int64'),
#  ('Middle East and North Africa', 'Libya'): Int64Index([98], dtype='int64'),
#  ('Middle East and North Africa', 'Morocco'): Int64Index([117], dtype='int64'),
#  ('Middle East and North Africa', 'Oman'): Int64Index([127], dtype='int64'),
#  ('Middle East and North Africa', 'Qatar'): Int64Index([136], dtype='int64'),
#  ('Middle East and North Africa',
#   'Saudi Arabia'): Int64Index([144], dtype='int64'),
#  ('Middle East and North Africa', 'Syria'): Int64Index([161], dtype='int64'),
#  ('Middle East and North Africa', 'Tunisia'): Int64Index([170], dtype='int64'),
#  ('Middle East and North Africa',
#   'United Arab Emirates'): Int64Index([175], dtype='int64'),
#  ('Middle East and North Africa', 'Yemen'): Int64Index([183], dtype='int64'),
#  ('Sub-Saharan Africa', 'Angola'): Int64Index([3], dtype='int64'),
#  ('Sub-Saharan Africa', 'Benin'): Int64Index([16], dtype='int64'),
#  ('Sub-Saharan Africa', 'Botswana'): Int64Index([20], dtype='int64'),
#  ('Sub-Saharan Africa', 'Burkina Faso'): Int64Index([24], dtype='int64'),
#  ('Sub-Saharan Africa', 'Burundi'): Int64Index([26], dtype='int64'),
#  ('Sub-Saharan Africa', 'Cabo Verde'): Int64Index([30], dtype='int64'),
#  ('Sub-Saharan Africa', 'Cameroon'): Int64Index([28], dtype='int64'),
#  ('Sub-Saharan Africa',
#   'Central African Republic'): Int64Index([31], dtype='int64'),
#  ('Sub-Saharan Africa', 'Chad'): Int64Index([32], dtype='int64'),
#  ('Sub-Saharan Africa', 'Comoros'): Int64Index([36], dtype='int64'),
#  ('Sub-Saharan Africa',
#   'Congo, Democratic Republic of the Congo'): Int64Index([37], dtype='int64'),
#  ('Sub-Saharan Africa', 'Congo, Republic of'): Int64Index([38], dtype='int64'),
#  ('Sub-Saharan Africa', "Côte d'Ivoire"): Int64Index([40], dtype='int64'),
#  ('Sub-Saharan Africa', 'Djibouti'): Int64Index([46], dtype='int64'),
#  ('Sub-Saharan Africa', 'Equatorial Guinea'): Int64Index([52], dtype='int64'),
#  ('Sub-Saharan Africa', 'Eritrea'): Int64Index([53], dtype='int64'),
#  ('Sub-Saharan Africa', 'Eswatini'): Int64Index([55], dtype='int64'),
#  ('Sub-Saharan Africa', 'Ethiopia'): Int64Index([56], dtype='int64'),
#  ('Sub-Saharan Africa', 'Gabon'): Int64Index([60], dtype='int64'),
#  ('Sub-Saharan Africa', 'Gambia'): Int64Index([61], dtype='int64'),
#  ('Sub-Saharan Africa', 'Ghana'): Int64Index([64], dtype='int64'),
#  ('Sub-Saharan Africa', 'Guinea'): Int64Index([67], dtype='int64'),
#  ('Sub-Saharan Africa', 'Guinea-Bissau'): Int64Index([68], dtype='int64'),
#  ('Sub-Saharan Africa', 'Kenya'): Int64Index([86], dtype='int64'),
#  ('Sub-Saharan Africa', 'Lesotho'): Int64Index([96], dtype='int64'),
#  ('Sub-Saharan Africa', 'Liberia'): Int64Index([97], dtype='int64'),
#  ('Sub-Saharan Africa', 'Madagascar'): Int64Index([104], dtype='int64'),
#  ('Sub-Saharan Africa', 'Malawi'): Int64Index([105], dtype='int64'),
#  ('Sub-Saharan Africa', 'Mali'): Int64Index([108], dtype='int64'),
#  ('Sub-Saharan Africa', 'Mauritania'): Int64Index([110], dtype='int64'),
#  ('Sub-Saharan Africa', 'Mauritius'): Int64Index([111], dtype='int64'),
#  ('Sub-Saharan Africa', 'Mozambique'): Int64Index([118], dtype='int64'),
#  ('Sub-Saharan Africa', 'Namibia'): Int64Index([119], dtype='int64'),
#  ('Sub-Saharan Africa', 'Niger'): Int64Index([124], dtype='int64'),
#  ('Sub-Saharan Africa', 'Nigeria'): Int64Index([125], dtype='int64'),
#  ('Sub-Saharan Africa', 'Rwanda'): Int64Index([139], dtype='int64'),
#  ('Sub-Saharan Africa', 'Senegal'): Int64Index([145], dtype='int64'),
#  ('Sub-Saharan Africa', 'Seychelles'): Int64Index([147], dtype='int64'),
#  ('Sub-Saharan Africa', 'Sierra Leone'): Int64Index([148], dtype='int64'),
#  ('Sub-Saharan Africa', 'Somalia'): Int64Index([153], dtype='int64'),
#  ('Sub-Saharan Africa', 'South Africa'): Int64Index([154], dtype='int64'),
#  ('Sub-Saharan Africa', 'Sudan'): Int64Index([157], dtype='int64'),
#  ('Sub-Saharan Africa',
#   'São Tomé and Príncipe'): Int64Index([143], dtype='int64'),
#  ('Sub-Saharan Africa', 'Tanzania'): Int64Index([164], dtype='int64'),
#  ('Sub-Saharan Africa', 'Togo'): Int64Index([167], dtype='int64'),
#  ('Sub-Saharan Africa', 'Uganda'): Int64Index([173], dtype='int64'),
#  ('Sub-Saharan Africa', 'Zambia'): Int64Index([184], dtype='int64'),
#  ('Sub-Saharan Africa', 'Zimbabwe'): Int64Index([185], dtype='int64')}
